# %%
data1 <- read.csv(file = "dataset1.csv", head =TRUE, sep =",");

# %%
data1_Fr <- data.frame(data1)
data1_Fr <- data1_Fr[,-c(1,2)]
dim(data1);
# Out:
# [1] 449  15

# %%
data1_Fr <- data.frame(data1)
data1_Fr <- data1_Fr[,-c(1,2)]

# %%
custom_glimpse <- function(df) {
  name <- deparse(substitute(df));
  print(name);
  data.frame(    
    col_name = colnames(df),
    col_index = 1:ncol(df),
    col_class = sapply(df, class),
    row.names = NULL
  )
}
custom_glimpse(data1_Fr)
# Out:
# [1] "data1_Fr"
#    col_name                     col_index col_class
# 1  tamanho_da_malha              1        integer
# 2  numero_defeitos               2        integer
# 3  LOC                           3        integer
# 4  cobertura_condicao            4        integer
# 5  requisitos_cobertos_condicao  5        integer
# 6  total_de_requistos_condicao   6        integer
# 7  cobertura_decisao             7        integer
# 8  requisitos_cobertos_decisao   8        integer
# 9  total_de_requistos_decisao    9        integer
# 10 cobertura_mcdc               10        integer
# 11 requisitos_cobertos_mcdc     11        integer
# 12 total_de_requistos_mcdc      12        integer
# 13 numero_de_condicoes          13        integer

# %%
#data1_Fr$cobertura_decisao <- as.numeric(as.character(data1_Fr$cobertura_decisao))
#data1_Fr$requisitos_cobertos_decisao <- as.numeric(as.character(data1_Fr$crequisitos_cobertos_decisao))

# %%
head(data1_Fr)
# Out:
#   tamanho_da_malha numero_defeitos LOC  cobertura_condicao
# 1    472           13               703 71
# 2   9711           15               701 77
# 3 500859           15               701 77
# 4    472           12              1186 55
# 5   9711           15              1186 62
# 6 500859           15              1186 63
#   requisitos_cobertos_condicao total_de_requistos_condicao cobertura_decisao
# 1 1659                         2317                        68
# 2 1807                         2317                        77
# 3 1807                         2317                        77
# 4 2159                         3866                        55
# 5 2433                         3866                        62
# 6 2447                         3866                        62
#   requisitos_cobertos_decisao total_de_requistos_decisao cobertura_mcdc
# 1 288                         421                        39
# 2 328                         421                        51
# 3 328                         421                        51
# 4 327                         588                        26
# 5 370                         588                        32
# 6 370                         588                        32
#   requisitos_cobertos_mcdc total_de_requistos_mcdc numero_de_condicoes
# 1 546                      1369                    5
# 2 705                      1369                    5
# 3 705                      1369                    5
# 4 582                      2227                    7
# 5 732                      2227                    7
# 6 732                      2227                    7

# %%
print("Sumario de dados data1")
summary(data1_Fr);
# Out:
# [1] "Sumario de dados data1"
#  tamanho_da_malha  numero_defeitos      LOC       cobertura_condicao
#  Min.   :      0   Min.   : 0.00   Min.   : 701   Min.   : 0.00
#  1st Qu.:     60   1st Qu.: 4.00   1st Qu.: 701   1st Qu.:42.00
#  Median :   1428   Median :14.00   Median :1186   Median :62.00
#  Mean   :  71119   Mean   :10.89   Mean   :2479   Mean   :58.19
#  3rd Qu.:  17496   3rd Qu.:15.00   3rd Qu.:5537   3rd Qu.:77.00
#  Max.   :1344605   Max.   :25.00   Max.   :5537   Max.   :90.00
#  requisitos_cobertos_condicao total_de_requistos_condicao cobertura_decisao
#  Min.   :    1                Min.   : 2317               Min.   : 0.00
#  1st Qu.: 1659                1st Qu.: 2317               1st Qu.:41.00
#  Median : 2184                Median : 3866               Median :62.00
#  Mean   : 4384                Mean   : 7261               Mean   :57.99
#  3rd Qu.: 5954                3rd Qu.:15566               3rd Qu.:77.00
#  Max.   :14155                Max.   :15566               Max.   :96.00
#  requisitos_cobertos_decisao total_de_requistos_decisao cobertura_mcdc
#  Min.   :   1.0              Min.   : 421               Min.   : 0.00
#  1st Qu.: 263.0              1st Qu.: 421               1st Qu.:14.00
#  Median : 337.0              Median : 588               Median :32.00
#  Mean   : 657.6              Mean   :1089               Mean   :32.26
#  3rd Qu.: 816.0              3rd Qu.:2254               3rd Qu.:51.00
#  Max.   :2179.0              Max.   :2254               Max.   :72.00
#  requisitos_cobertos_mcdc total_de_requistos_mcdc numero_de_condicoes
#  Min.   :   1             Min.   :1369            Min.   :5.000
#  1st Qu.: 389             1st Qu.:1369            1st Qu.:5.000
#  Median : 705             Median :2227            Median :5.000
#  Mean   :1464             Mean   :4175            Mean   :5.668
#  3rd Qu.: 936             3rd Qu.:8910            3rd Qu.:7.000
#  Max.   :6484             Max.   :8910            Max.   :7.000

# %%
#Histograma

# %%
par(mfrow=c(2,2))

hist(data1_Fr[["tamanho_da_malha"]],main="tamanho_da_malha")
hist(data1_Fr[["numero_defeitos"]],main="numero_defeitos")
hist(data1_Fr[["LOC"]],main="LOC")
hist(data1_Fr[["cobertura_condicao"]],main="cobertura_condicao")
hist(data1_Fr[["requisitos_cobertos_condicao"]],main="requisitos_cobertos_condicao")
hist(data1_Fr[["total_de_requistos_condicao"]],main="total_de_requistos_condicao")
hist(data1_Fr[["cobertura_decisao"]],main="cobertura_decisao")
hist(data1_Fr[["requisitos_cobertos_decisao"]],main="requisitos_cobertos_decisao")
hist(data1_Fr[["total_de_requistos_decisao"]],main="total_de_requistos_decisao")
hist(data1_Fr[["cobertura_mcdc"]],main="cobertura_mcdc")
hist(data1_Fr[["requisitos_cobertos_mcdc"]],main="requisitos_cobertos_mcdc")
hist(data1_Fr[["total_de_requistos_mcdc"]],main="total_de_requistos_mcdc")
hist(data1_Fr[["numero_de_condicoes"]],main="numero_de_condicoes")
# Out:
# Plot with title “cobertura_condicao”
# Plot with title “requisitos_cobertos_decisao”
# Plot with title “total_de_requistos_mcdc”
# Plot with title “numero_de_condicoes”

# %%
install.packages("corrplot",lib='/opt/R/3.6.0/lib/R/library/corrplot')
# Out:
# Warning message in install.packages("corrplot", lib = "/opt/R/3.6.0/lib/R/library/corrplot"):
# “'lib = "/opt/R/3.6.0/lib/R/library/corrplot"' is not writable”
# Error in install.packages("corrplot", lib = "/opt/R/3.6.0/lib/R/library/corrplot"): unable to install packages
# Traceback:
#
# 1. install.packages("corrplot", lib = "/opt/R/3.6.0/lib/R/library/corrplot")
# 2. stop("unable to install packages")

# %%
library(corrplot)
c <- cor(data1_Fr)
# Out:
# corrplot 0.92 loaded

# %% [raw]
# corrplot(c)
